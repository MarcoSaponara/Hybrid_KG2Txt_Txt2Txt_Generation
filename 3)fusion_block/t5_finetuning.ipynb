# %%
# !python --version
# Out:
# Python 3.7.12

# %%
# !nvidia-smi
# Out:
# Thu Mar 24 14:49:56 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8    29W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install sentencepiece
# !pip install transformers==2.9.0 
# !pip install pytorch_lightning==0.7.5
# Out:
# ...
#      |████████████████████████████████| 1.2 MB 5.5 MB/s
# ...
#      |████████████████████████████████| 635 kB 5.3 MB/s
# ...
#      |████████████████████████████████| 895 kB 36.3 MB/s
# ...
#      |████████████████████████████████| 5.6 MB 29.5 MB/s
# ...
#      |████████████████████████████████| 233 kB 5.4 MB/s
# ...
#      |████████████████████████████████| 829 kB 31.5 MB/s
# ...
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=58f6145311f3fb2d2d76d1f8006ddcef711eac56a366e3b81e369a93417df140
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
# Successfully built future
# ...
#   Attempting uninstall: future
#     Found existing installation: future 0.16.0
#     Uninstalling future-0.16.0:
#       Successfully uninstalled future-0.16.0
# ...

# %%
# !git clone https://github.com/MarcoSaponara/Hybrid_KG2Txt_Txt2Txt_Generation.git repo
# Out:
# Cloning into 'repo'...
# remote: Enumerating objects: 134, done.
# remote: Counting objects: 100% (134/134), done.
# remote: Compressing objects: 100% (117/117), done.
# remote: Total 134 (delta 22), reused 89 (delta 5), pack-reused 0
# Receiving objects: 100% (134/134), 371.99 KiB | 4.59 MiB/s, done.
# Resolving deltas: 100% (22/22), done.

# %%
# %cd ./repo/3)fusion_block
# Out:
# /content/repo/3)fusion_block

# %%
# !mkdir ./my_t5
# !mkdir ./my_t5_base

# %%
# !cp './data/debug.jsonl' './data/train.jsonl'
# !cp './data/debug.jsonl' './data/val.jsonl'
# !cp './data/debug.jsonl' './data/test.jsonl'

# %%
# !python ./src/scripts/t5_finetuning.py
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# INFO:transformers.file_utils:PyTorch version 1.10.0+cu111 available.
# INFO:transformers.file_utils:TensorFlow version 2.8.0 available.
# INFO:transformers.file_utils:https://s3.amazonaws.com/models.huggingface.co/bert/t5-spiece.model not found in cache or force_download set to True, downloading to /root/.cache/torch/transformers/tmpcak5xooe
# Downloading: 100% 792k/792k [00:00<00:00, 5.07MB/s]
# INFO:transformers.file_utils:storing https://s3.amazonaws.com/models.huggingface.co/bert/t5-spiece.model in cache at /root/.cache/torch/transformers/68f1b8dbca4350743bb54b8c4169fd38cbabaad564f85a9239337a8d0342af9f.9995af32582a1a7062cb3173c118cb7b4636fa03feb967340f20fc37406f021f
# ...
